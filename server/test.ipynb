# %%
import pandas as pd

df = pd.read_csv('WCA_export/competitions.tsv', sep='\t')

# %%
df.head(20)
# Out:
#                               id                               name  \
# 0                  100Merito2018                   100º Mérito 2018
# 1     100YearsRepublicAnkara2023     100 Years Republic Ankara 2023
# 2   100YearsRepublicIstanbul2023   100 Years Republic İstanbul 2023
# 3       100YilMBACubeWeekend2023     100. Yıl MBA Cube Weekend 2023
# 4     10AniversarioGuatemala2023  Décimo Aniversario Guatemala 2023
# 5       10doRioGrandedoNorte2018    10º do Rio Grande do Norte 2018
# 6      10JohrWilerWurfelfast2024      10 Johr Wiler Würfelfäst 2024
# 7   10thAnniversaryCervantes2024    10th Anniversary Cervantes 2024
# 8           12SidesofSilesia2018           12 Sides of Silesia 2018
# 9    150thCubeMeetinginBrest2017   150th Cube Meeting in Brest 2017
# 10        15AnosSanSilvestre2024         15 Años San Silvestre 2024
# 11   1aLordagskubeniVasteras2024   1:a Lördagskuben i Västerås 2024
# 12                      1AVG2013             1 AVG competition 2013
# ...
